# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as snb

# %%
amazon_df=pd.read_csv(r"C:\Users\HP\Documents\ALL EDUREKA PRACTICE CODES\All Data Files\Amazon_dataset.csv")

# %%
amazon_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-10-18  119.059998  119.519997  114.790001  116.360001  116.360001
# 1    2022-10-19  114.709999  116.589996  113.220001  115.070000  115.070000
# 2    2022-10-20  113.830002  118.239998  113.510002  115.250000  115.250000
# 3    2022-10-21  114.790001  119.589996  114.500000  119.320000  119.320000
# 4    2022-10-24  119.980003  120.389999  116.570000  119.820000  119.820000
# ..          ...         ...         ...         ...         ...         ...
# 246  2023-10-11  129.740005  132.050003  129.610001  131.830002  131.830002
# 247  2023-10-12  132.169998  134.479996  131.229996  132.330002  132.330002
# 248  2023-10-13  132.979996  133.309998  128.949997  129.789993  129.789993
# 249  2023-10-16  130.690002  133.070007  130.429993  132.550003  132.550003
# 250  2023-10-17  130.389999  132.580002  128.710007  131.470001  131.470001
#
#        Volume
# 0    65607400
# 1    47198100
# ...

# %%
amazon_df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
amazon_df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   111.624901  113.166892  110.027570  111.638526  111.638526
# std     17.693054   17.729655   17.725741   17.726630   17.726630
# min     82.800003   83.480003   81.430000   81.820000   81.820000
# 25%     96.035000   97.544998   94.195000   96.259998   96.259998
# 50%    105.260002  106.790001  104.330002  105.660004  105.660004
# 75%    129.005004  130.430000  127.460003  128.974998  128.974998
# max    145.080002  145.860001  142.949997  144.850006  144.850006
#
#              Volume
# count  2.510000e+02
# mean   6.571505e+07
# std    2.672245e+07
# min    2.826480e+07
# 25%    4.858070e+07
# 50%    5.892840e+07
# 75%    7.277790e+07
# max    2.231334e+08

# %%
amazon_df.shape
# Out:
# (251, 7)

# %%
amazon_df['Date'] = pd.to_datetime(amazon_df['Date'])
amazon_df = amazon_df.sort_values('Date')

# %%
amazon_df.loc[:, 'Daily Price Change'] = amazon_df['Adj Close'].diff()

# %%
amazon_df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-10-18  119.059998  119.519997  114.790001  116.360001  116.360001
# 1   2022-10-19  114.709999  116.589996  113.220001  115.070000  115.070000
# 2   2022-10-20  113.830002  118.239998  113.510002  115.250000  115.250000
# 3   2022-10-21  114.790001  119.589996  114.500000  119.320000  119.320000
# 4   2022-10-24  119.980003  120.389999  116.570000  119.820000  119.820000
# ..         ...         ...         ...         ...         ...         ...
# 246 2023-10-11  129.740005  132.050003  129.610001  131.830002  131.830002
# 247 2023-10-12  132.169998  134.479996  131.229996  132.330002  132.330002
# 248 2023-10-13  132.979996  133.309998  128.949997  129.789993  129.789993
# 249 2023-10-16  130.690002  133.070007  130.429993  132.550003  132.550003
# 250 2023-10-17  130.389999  132.580002  128.710007  131.470001  131.470001
#
#        Volume  Daily Price Change
# ...

# %%
plt.figure(figsize=(12, 6))
plt.plot(amazon_df.index, amazon_df['Volume'], label='Volume')
plt.title('Amazon Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()

# %%
amazon_df.loc[:,'Daily Return'] = amazon_df['Adj Close'].pct_change()
amazon_df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2022-10-18  119.059998  119.519997  114.790001  116.360001  116.360001
# 1 2022-10-19  114.709999  116.589996  113.220001  115.070000  115.070000
# 2 2022-10-20  113.830002  118.239998  113.510002  115.250000  115.250000
# 3 2022-10-21  114.790001  119.589996  114.500000  119.320000  119.320000
# 4 2022-10-24  119.980003  120.389999  116.570000  119.820000  119.820000
#
#      Volume  Daily Price Change  Daily Return
# 0  65607400                 NaN           NaN
# 1  47198100           -1.290001     -0.011086
# 2  48795100            0.180000      0.001564
# 3  55660500            4.070000      0.035315
# 4  49531500            0.500000      0.004190

# %%
amazon_df.loc[:,'Trend'] = ['Up' if x > 0 else 'Down' if x < 0 else 'No Change' for x in amazon_df['Daily Return']]

# %%
amazon_df
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-10-18  119.059998  119.519997  114.790001  116.360001  116.360001
# 1   2022-10-19  114.709999  116.589996  113.220001  115.070000  115.070000
# 2   2022-10-20  113.830002  118.239998  113.510002  115.250000  115.250000
# 3   2022-10-21  114.790001  119.589996  114.500000  119.320000  119.320000
# 4   2022-10-24  119.980003  120.389999  116.570000  119.820000  119.820000
# ..         ...         ...         ...         ...         ...         ...
# 246 2023-10-11  129.740005  132.050003  129.610001  131.830002  131.830002
# 247 2023-10-12  132.169998  134.479996  131.229996  132.330002  132.330002
# 248 2023-10-13  132.979996  133.309998  128.949997  129.789993  129.789993
# 249 2023-10-16  130.690002  133.070007  130.429993  132.550003  132.550003
# 250 2023-10-17  130.389999  132.580002  128.710007  131.470001  131.470001
#
#        Volume  Daily Price Change  Daily Return      Trend
# ...

# %%
trend_counts = amazon_df['Trend'].value_counts()
plt.pie(trend_counts, labels=trend_counts.index, autopct='%1.1f%%')
plt.title('Trend Frequency')
plt.show()

# %%
correlation_matrix = amazon_df.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12104\4217704915.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = amazon_df.corr()

# %%
correlation_matrix
# Out:
#                         Open      High       Low     Close  Adj Close  \
# Open                1.000000  0.997467  0.997425  0.993475   0.993475
# High                0.997467  1.000000  0.997875  0.997408   0.997408
# Low                 0.997425  0.997875  1.000000  0.997700   0.997700
# Close               0.993475  0.997408  0.997700  1.000000   1.000000
# Adj Close           0.993475  0.997408  0.997700  1.000000   1.000000
# Volume             -0.319214 -0.300293 -0.339156 -0.321981  -0.321981
# Daily Price Change  0.007405  0.046820  0.048630  0.088687   0.088687
# Daily Return        0.001900  0.042010  0.041922  0.082997   0.082997
#
#                       Volume  Daily Price Change  Daily Return
# Open               -0.319214            0.007405      0.001900
# High               -0.300293            0.046820      0.042010
# Low                -0.339156            0.048630      0.041922
# Close              -0.321981            0.088687      0.082997
# ...

# %%
from concurrent.futures import ThreadPoolExecutor
def read_csv(file_path):
    return pd.read_csv(file_path)
file_paths = [r"C:\Users\HP\Documents\ALL EDUREKA PRACTICE CODES\All Data Files\apple_ds.csv",r"C:\Users\HP\Documents\ALL EDUREKA PRACTICE CODES\All Data Files\google_ds.csv",r"C:\Users\HP\Documents\ALL EDUREKA PRACTICE CODES\All Data Files\msft_ds.csv",r"C:\Users\HP\Documents\ALL EDUREKA PRACTICE CODES\All Data Files\Amazon_dataset.csv"]
with ThreadPoolExecutor() as executor:
    dataframes = list(executor.map(read_csv, file_paths))
apple_df, google_df, msft_df, amzn_df = dataframes

# %%
dataframes
# Out:
# [           Date        Open        High         Low       Close   Adj Close  \
#  0    2022-10-18  145.490005  146.699997  140.610001  143.750000  142.902252
#  1    2022-10-19  141.690002  144.949997  141.500000  143.860001  143.011612
#  2    2022-10-20  143.020004  145.889999  142.649994  143.389999  142.544373
#  3    2022-10-21  142.869995  147.850006  142.649994  147.270004  146.401505
#  4    2022-10-24  147.190002  150.229996  146.000000  149.449997  148.568634
#  ..          ...         ...         ...         ...         ...         ...
#  246  2023-10-11  178.199997  179.850006  177.600006  179.800003  179.800003
#  247  2023-10-12  180.070007  182.339996  179.039993  180.710007  180.710007
#  248  2023-10-13  181.419998  181.929993  178.139999  178.850006  178.850006
#  249  2023-10-16  176.750000  179.080002  176.509995  178.720001  178.720001
#  250  2023-10-17  176.649994  178.419998  174.800003  177.149994  177.149994
#
#         Volume
#  0    99136600
# ...

# %%
apple_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-10-18  145.490005  146.699997  140.610001  143.750000  142.902252
# 1    2022-10-19  141.690002  144.949997  141.500000  143.860001  143.011612
# 2    2022-10-20  143.020004  145.889999  142.649994  143.389999  142.544373
# 3    2022-10-21  142.869995  147.850006  142.649994  147.270004  146.401505
# 4    2022-10-24  147.190002  150.229996  146.000000  149.449997  148.568634
# ..          ...         ...         ...         ...         ...         ...
# 246  2023
# ..          ...         ...         ...         ...         ...         ...
# 246  2023-10-11  331.209991  332.820007  329.140015  332.420013  332.420013
# 247  2023-10-12  330.570007  333.630005  328.720001  331.160004  331.160004
# 248  2023-10-13  332.380005  333.829987  326.359985  327.730011  327.730011
# 249  2023-10-16  331.049988  336.140015  330.600006  332.640015  332.640015
# 250  2023-10-17  329.589996  333.459991  327.410004  332.059998  332.059998
#
#        Volume
# 0    26329600
# 1    19985700
# ...

# %%
msft_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
msft_df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
msft_df.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  251.000000  251.000000  251.000000  251.000000  251.000000
# mean   288.585578  291.752988  285.674461  288.835219  287.768192
# std     40.462705   40.480289   40.281378   40.308984   40.858722
# min    217.550003  220.410004  213.429993  214.250000  212.199982
# 25%    247.354996  250.964996  245.540001  248.080002  246.398720
# 50%    287.000000  289.899994  284.709991  288.450012  287.212738
# 75%    328.474991  331.005005  324.940002  328.085007  327.745011
# max    361.750000  366.779999  352.440002  359.489990  358.730469
#
#              Volume
# count  2.510000e+02
# mean   2.825151e+07
# std    1.121398e+07
# min    9.200800e+06
# 25%    2.127565e+07
# 50%    2.574000e+07
# 75%    3.096025e+07
# max    8.610200e+07

# %%
msft_df.shape
# Out:
# (251, 7)

# %%
stock_data_df=pd.concat([apple_df,google_df,msft_df])

# %%
stock_data_df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-10-18  145.490005  146.699997  140.610001  143.750000  142.902252
# 1    2022-10-19  141.690002  144.949997  141.500000  143.860001  143.011612
# 2    2022-10-20  143.020004  145.889999  142.649994  143.389999  142.544373
# 3    2022-10-21  142.869995  147.850006  142.649994  147.270004  146.401505
# 4    2022-10-24  147.190002  150.229996  146.000000  149.449997  148.568634
# ..          ...         ...         ...         ...         ...         ...
# 246  2023-10-11  331.209991  332.820007  329.140015  332.420013  332.420013
# 247  2023-10-12  330.570007  333.630005  328.720001  331.160004  331.160004
# 248  2023-10-13  332.380005  333.829987  326.359985  327.730011  327.730011
# 249  2023-10-16  331.049988  336.140015  330.600006  332.640015  332.640015
# 250  2023-10-17  329.589996  333.459991  327.410004  332.059998  332.059998
#
#        Volume
# 0    99136600
# 1    61758300
# ...

# %%
stock_data_df.sort_values(by='Date', inplace=True)

# %%
stock_data_df.loc[:, 'Daily Price Change'] = stock_data_df['Adj Close'].diff()

# %%
stock_data_df.head(60)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-10-18  145.490005  146.699997  140.610001  143.750000  142.902252
# 0   2022-10-18  103.940002  104.220001  100.650002  101.389999  101.389999
# 0   2022-10-18  243.240005  243.929993  235.369995  238.500000  236.217941
# 1   2022-10-19  141.690002  144.949997  141.500000  143.860001  143.011612
# 1   2022-10-19  100.699997  101.658997   99.635002  100.290001  100.290001
# 1   2022-10-19  237.039993  239.610001  234.289993  236.479996  234.217270
# 2   2022-10-20  143.020004  145.889999  142.649994  143.389999  142.544373
# 2   2022-10-20  100.820000  103.000000   99.970001  100.529999  100.529999
# 2   2022-10-20  235.770004  241.309998  234.869995  236.149994  233.890442
# 3   2022-10-21  142.869995  147.850006  142.649994  147.270004  146.401505
# 3   2022-10-21   98.459999  101.620003   98.230003  101.480003  101.480003
# ...

# %%
plt.figure(figsize=(12, 6))
plt.scatter(stock_data_df.index, stock_data_df['Volume'], label='Volume')
plt.title('Amazon Stock Volume Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.grid(True)
plt.legend()
plt.show()

# %%
stock_data_df.loc[:,'Daily Return'] = stock_data_df['Adj Close'].pct_change()
stock_data_df.head(50)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2022-10-18  145.490005  146.699997  140.610001  143.750000  142.902252
# 0   2022-10-18  103.940002  104.220001  100.650002  101.389999  101.389999
# 0   2022-10-18  243.240005  243.929993  235.369995  238.500000  236.217941
# 1   2022-10-19  141.690002  144.949997  141.500000  143.860001  143.011612
# 1   2022-10-19  100.699997  101.658997   99.635002  100.290001  100.290001
# 1   2022-10-19  237.039993  239.610001  234.289993  236.479996  234.217270
# 2   2022-10-20  143.020004  145.889999  142.649994  143.389999  142.544373
# 2   2022-10-20  100.820000  103.000000   99.970001  100.529999  100.529999
# 2   2022-10-20  235.770004  241.309998  234.869995  236.149994  233.890442
# 3   2022-10-21  142.869995  147.850006  142.649994  147.270004  146.401505
# 3   2022-10-21   98.459999  101.620003   98.230003  101.480003  101.480003
# ...

# %%
stock_data_df.loc[:,'Trend'] = ['Up' if x > 0 else 'Down' if x < 0 else 'No Change' for x in stock_data_df['Daily Return']]

# %%
stock_data_df.head(25)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-10-18  145.490005  146.699997  140.610001  143.750000  142.902252
# 0  2022-10-18  103.940002  104.220001  100.650002  101.389999  101.389999
# 0  2022-10-18  243.240005  243.929993  235.369995  238.500000  236.217941
# 1  2022-10-19  141.690002  144.949997  141.500000  143.860001  143.011612
# 1  2022-10-19  100.699997  101.658997   99.635002  100.290001  100.290001
# 1  2022-10-19  237.039993  239.610001  234.289993  236.479996  234.217270
# 2  2022-10-20  143.020004  145.889999  142.649994  143.389999  142.544373
# 2  2022-10-20  100.820000  103.000000   99.970001  100.529999  100.529999
# 2  2022-10-20  235.770004  241.309998  234.869995  236.149994  233.890442
# 3  2022-10-21  142.869995  147.850006  142.649994  147.270004  146.401505
# 3  2022-10-21   98.459999  101.620003   98.230003  101.480003  101.480003
# 3  2022-10-21  234.740005  243.000000  234.500000  242.119995  239.803299
# ...

# %%
trend_counts = stock_data_df['Trend'].value_counts()
plt.pie(trend_counts, labels=trend_counts.index, autopct='%1.1f%%')
plt.title('Trend Frequency')
plt.legend()
plt.show()

# %%
correlation_matrix = stock_data_df.corr()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12104\3294653624.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = stock_data_df.corr()

# %%
correlation_matrix
# Out:
#                         Open      High       Low     Close  Adj Close  \
# Open                1.000000  0.999706  0.999758  0.999351   0.999338
# High                0.999706  1.000000  0.999714  0.999748   0.999710
# Low                 0.999758  0.999714  1.000000  0.999732   0.999737
# Close               0.999351  0.999748  0.999732  1.000000   0.999979
# Adj Close           0.999338  0.999710  0.999737  0.999979   1.000000
# Volume             -0.193206 -0.189856 -0.196461 -0.193275  -0.194277
# Daily Price Change  0.813396  0.815188  0.812307  0.814162   0.812894
# Daily Return        0.850747  0.852445  0.849726  0.851691   0.849786
#
#                       Volume  Daily Price Change  Daily Return
# Open               -0.193206            0.813396      0.850747
# High               -0.189856            0.815188      0.852445
# Low                -0.196461            0.812307      0.849726
# Close              -0.193275            0.814162      0.851691
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Correlation Matrix of Daily Returns')
plt.show()

# %% [markdown]
# # END
